# %% [markdown]
# Import necessary libraries

# %%
# !pip install warning
# Out:
# ERROR: Could not find a version that satisfies the requirement warning (from versions: none)
# ERROR: No matching distribution found for warning

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# Load and understand data

# %%
df=pd.read_csv('D:\coded_jupy\mushrooms.csv')

# %%
df.head()
# Out:
#   class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0     p         x           s         n       t    p               f
# 1     e         x           s         y       t    a               f
# 2     e         b           s         w       t    l               f
# 3     p         x           y         w       t    p               f
# 4     e         x           s         g       f    n               f
#
#   gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 0            c         n          k  ...                        s
# 1            c         b          k  ...                        s
# 2            c         b          n  ...                        s
# 3            c         n          n  ...                        s
# 4            w         b          k  ...                        s
#
#   stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 0                      w                      w         p          w
# 1                      w                      w         p          w
# 2                      w                      w         p          w
# 3                      w                      w         p          w
# 4                      w                      w         p          w
#
#   ring-number ring-type spore-print-color population habitat
# 0           o         p                 k          s       u
# 1           o         p                 n          n       g
# 2           o         p                 n          n       m
# 3           o         p                 k          s       u
# 4           o         e                 n          a       g
#
# [5 rows x 23 columns]

# %%
df.shape
# Out:
# (8124, 23)

# %%
df.columns
# Out:
# Index(['class', 'cap-shape', 'cap-surface', 'cap-color', 'bruises', 'odor',
#        'gill-attachment', 'gill-spacing', 'gill-size', 'gill-color',
#        'stalk-shape', 'stalk-root', 'stalk-surface-above-ring',
#        'stalk-surface-below-ring', 'stalk-color-above-ring',
#        'stalk-color-below-ring', 'veil-type', 'veil-color', 'ring-number',
#        'ring-type', 'spore-print-color', 'population', 'habitat'],
#       dtype='object')

# %%
df.describe()
# Out:
#        class cap-shape cap-surface cap-color bruises  odor gill-attachment  \
# count   8124      8124        8124      8124    8124  8124            8124
# unique     2         6           4        10       2     9               2
# top        e         x           y         n       f     n               f
# freq    4208      3656        3244      2284    4748  3528            7914
#
#        gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# count          8124      8124       8124  ...                     8124
# unique            2         2         12  ...                        4
# top               c         b          b  ...                        s
# freq           6812      5612       1728  ...                     4936
#
#        stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# count                    8124                   8124      8124       8124
# unique                      9                      9         1          4
# top                         w                      w         p          w
# freq                     4464                   4384      8124       7924
#
#        ring-number ring-type spore-print-color population habitat
# count         8124      8124              8124       8124    8124
# unique           3         5                 9          6       7
# top              o         p                 w          v       d
# freq          7488      3968              2388       4040    3148
#
# [4 rows x 23 columns]

# %%
df.dtypes
# Out:
# class                       object
# cap-shape                   object
# cap-surface                 object
# cap-color                   object
# bruises                     object
# odor                        object
# gill-attachment             object
# gill-spacing                object
# gill-size                   object
# gill-color                  object
# stalk-shape                 object
# stalk-root                  object
# stalk-surface-above-ring    object
# stalk-surface-below-ring    object
# stalk-color-above-ring      object
# stalk-color-below-ring      object
# veil-type                   object
# veil-color                  object
# ring-number                 object
# ring-type                   object
# spore-print-color           object
# population                  object
# habitat                     object
# dtype: object

# %%
df.isna().sum()
# Out:
# class                       0
# cap-shape                   0
# cap-surface                 0
# cap-color                   0
# bruises                     0
# odor                        0
# gill-attachment             0
# gill-spacing                0
# gill-size                   0
# gill-color                  0
# stalk-shape                 0
# stalk-root                  0
# stalk-surface-above-ring    0
# stalk-surface-below-ring    0
# stalk-color-above-ring      0
# stalk-color-below-ring      0
# veil-type                   0
# veil-color                  0
# ring-number                 0
# ring-type                   0
# spore-print-color           0
# population                  0
# habitat                     0
# dtype: int64

# %%
for column in df.columns:
    print(column, ":",df[column].unique())
# Out:
# class : ['p' 'e']
# cap-shape : ['x' 'b' 's' 'f' 'k' 'c']
# cap-surface : ['s' 'y' 'f' 'g']
# cap-color : ['n' 'y' 'w' 'g' 'e' 'p' 'b' 'u' 'c' 'r']
# bruises : ['t' 'f']
# odor : ['p' 'a' 'l' 'n' 'f' 'c' 'y' 's' 'm']
# gill-attachment : ['f' 'a']
# gill-spacing : ['c' 'w']
# gill-size : ['n' 'b']
# gill-color : ['k' 'n' 'g' 'p' 'w' 'h' 'u' 'e' 'b' 'r' 'y' 'o']
# stalk-shape : ['e' 't']
# stalk-root : ['e' 'c' 'b' 'r' '?']
# stalk-surface-above-ring : ['s' 'f' 'k' 'y']
# stalk-surface-below-ring : ['s' 'f' 'y' 'k']
# stalk-color-above-ring : ['w' 'g' 'p' 'n' 'b' 'e' 'o' 'c' 'y']
# stalk-color-below-ring : ['w' 'p' 'g' 'b' 'n' 'e' 'y' 'o' 'c']
# veil-type : ['p']
# veil-color : ['w' 'n' 'o' 'y']
# ring-number : ['o' 't' 'n']
# ring-type : ['p' 'e' 'l' 'f' 'n']
# spore-print-color : ['k' 'n' 'u' 'h' 'w' 'r' 'o' 'y' 'b']
# population : ['s' 'n' 'a' 'v' 'y' 'c']
# habitat : ['u' 'g' 'm' 'd' 'p' 'w' 'l']

# %%
for i in df.columns:
    print(i)
    print(df[i].value_counts())
    print("_ _ _ _ _ _ _ _ _ _ _ _ _ _")
# Out:
# class
# e    4208
# p    3916
# Name: class, dtype: int64
# _ _ _ _ _ _ _ _ _ _ _ _ _ _
# cap-shape
# x    3656
# f    3152
# k     828
# b     452
# s      32
# c       4
# Name: cap-shape, dtype: int64
# _ _ _ _ _ _ _ _ _ _ _ _ _ _
# cap-surface
# y    3244
# s    2556
# f    2320
# g       4
# Name: cap-surface, dtype: int64
# _ _ _ _ _ _ _ _ _ _ _ _ _ _
# cap-color
# n    2284
# g    1840
# e    1500
# y    1072
# w    1040
# b     168
# p     144
# c      44
# u      16
# r      16
# Name: cap-color, dtype: int64
# _ _ _ _ _ _ _ _ _ _ _ _ _ _
# bruises
# f    4748
# t    3376
# Name: bruises, dtype: int64
# _ _ _ _ _ _ _ _ _ _ _ _ _ _
# odor
# n    3528
# f    2160
# y     576
# s     576
# a     400
# l     400
# p     256
# c     192
# m      36
# Name: odor, dtype: int64
# _ _ _ _ _ _ _ _ _ _ _ _ _ _
# gill-attachment
# f    7914
# a     210
# Name: gill-attachment, dtype: int64
# _ _ _ _ _ _ _ _ _ _ _ _ _ _
# gill-spacing
# c    6812
# w    1312
# Name: gill-spacing, dtype: int64
# _ _ _ _ _ _ _ _ _ _ _ _ _ _
# gill-size
# b    5612
# n    2512
# Name: gill-size, dtype: int64
# _ _ _ _ _ _ _ _ _ _ _ _ _ _
# gill-color
# b    1728
# p    1492
# w    1202
# n    1048
# g     752
# h     732
# u     492
# k     408
# e      96
# y      86
# o      64
# r      24
# Name: gill-color, dtype: int64
# _ _ _ _ _ _ _ _ _ _ _ _ _ _
# stalk-shape
# t    4608
# e    3516
# Name: stalk-shape, dtype: int64
# _ _ _ _ _ _ _ _ _ _ _ _ _ _
# stalk-root
# b    3776
# ?    2480
# e    1120
# c     556
# r     192
# Name: stalk-root, dtype: int64
# _ _ _ _ _ _ _ _ _ _ _ _ _ _
# stalk-surface-above-ring
# s    5176
# k    2372
# f     552
# y      24
# Name: stalk-surface-above-ring, dtype: int64
# _ _ _ _ _ _ _ _ _ _ _ _ _ _
# stalk-surface-below-ring
# s    4936
# k    2304
# f     600
# y     284
# Name: stalk-surface-below-ring, dtype: int64
# _ _ _ _ _ _ _ _ _ _ _ _ _ _
# stalk-color-above-ring
# w    4464
# p    1872
# g     576
# n     448
# b     432
# o     192
# e      96
# c      36
# y       8
# Name: stalk-color-above-ring, dtype: int64
# _ _ _ _ _ _ _ _ _ _ _ _ _ _
# stalk-color-below-ring
# w    4384
# p    1872
# g     576
# n     512
# b     432
# o     192
# e      96
# c      36
# y      24
# Name: stalk-color-below-ring, dtype: int64
# _ _ _ _ _ _ _ _ _ _ _ _ _ _
# veil-type
# p    8124
# Name: veil-type, dtype: int64
# _ _ _ _ _ _ _ _ _ _ _ _ _ _
# veil-color
# w    7924
# n      96
# o      96
# y       8
# Name: veil-color, dtype: int64
# _ _ _ _ _ _ _ _ _ _ _ _ _ _
# ring-number
# o    7488
# t     600
# n      36
# Name: ring-number, dtype: int64
# _ _ _ _ _ _ _ _ _ _ _ _ _ _
# ring-type
# p    3968
# e    2776
# l    1296
# f      48
# n      36
# Name: ring-type, dtype: int64
# _ _ _ _ _ _ _ _ _ _ _ _ _ _
# spore-print-color
# w    2388
# n    1968
# k    1872
# h    1632
# r      72
# u      48
# o      48
# y      48
# b      48
# Name: spore-print-color, dtype: int64
# _ _ _ _ _ _ _ _ _ _ _ _ _ _
# population
# v    4040
# y    1712
# s    1248
# n     400
# a     384
# c     340
# Name: population, dtype: int64
# _ _ _ _ _ _ _ _ _ _ _ _ _ _
# habitat
# d    3148
# g    2148
# p    1144
# l     832
# u     368
# m     292
# w     192
# Name: habitat, dtype: int64
# _ _ _ _ _ _ _ _ _ _ _ _ _ _

# %%
#stalk root contain "?"
df['stalk-root'].unique()
# Out:
# array(['e', 'c', 'b', 'r', '?'], dtype=object)

# %%
# replace "?" to "NaN" 
df.replace('?',np.nan,inplace=True)

# %%
df['stalk-root'].unique()
# Out:
# array(['e', 'c', 'b', 'r', nan], dtype=object)

# %%
df.isna().sum()
# Out:
# class                          0
# cap-shape                      0
# cap-surface                    0
# cap-color                      0
# bruises                        0
# odor                           0
# gill-attachment                0
# gill-spacing                   0
# gill-size                      0
# gill-color                     0
# stalk-shape                    0
# stalk-root                  2480
# stalk-surface-above-ring       0
# stalk-surface-below-ring       0
# stalk-color-above-ring         0
# stalk-color-below-ring         0
# veil-type                      0
# veil-color                     0
# ring-number                    0
# ring-type                      0
# spore-print-color              0
# population                     0
# habitat                        0
# dtype: int64

# %%
df.head()
# Out:
#   class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0     p         x           s         n       t    p               f
# 1     e         x           s         y       t    a               f
# 2     e         b           s         w       t    l               f
# 3     p         x           y         w       t    p               f
# 4     e         x           s         g       f    n               f
#
#   gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 0            c         n          k  ...                        s
# 1            c         b          k  ...                        s
# 2            c         b          n  ...                        s
# 3            c         n          n  ...                        s
# 4            w         b          k  ...                        s
#
#   stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 0                      w                      w         p          w
# 1                      w                      w         p          w
# 2                      w                      w         p          w
# 3                      w                      w         p          w
# 4                      w                      w         p          w
#
#   ring-number ring-type spore-print-color population habitat
# 0           o         p                 k          s       u
# 1           o         p                 n          n       g
# 2           o         p                 n          n       m
# 3           o         p                 k          s       u
# 4           o         e                 n          a       g
#
# [5 rows x 23 columns]

# %%
column_list = list(df.columns.values)
column_list.remove('class')
for i in column_list:
    plt.figure(figsize=(7, 7))
    splot = sns.countplot(data=df, x=i,hue='class',order = df[i].value_counts().index,palette=['#7AA225',"#FAAE7C"])
    for p in splot.patches:
        splot.annotate(format(p.get_height(), '.1f'),
                       (p.get_x() + p.get_width() / 2., p.get_height()),
                       ha='center', va='center',
                       xytext=(0, 9),
                       textcoords='offset points')
    plt.legend(['Poisonous', 'Edible'], loc='upper right')
    plt.title('Distribution of the Mushrooms by their Classes and {}'.format(i))
    plt.show()

# %%
#label Encoding

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
for column in df.columns:
    df[column]=le.fit_transform(df[column])
df.head()
# Out:
#    class  cap-shape  cap-surface  cap-color  bruises  odor  gill-attachment  \
# 0      1          5            2          4        1     6                1
# 1      0          5            2          9        1     0                1
# 2      0          0            2          8        1     3                1
# 3      1          5            3          8        1     6                1
# 4      0          5            2          3        0     5                1
#
#    gill-spacing  gill-size  gill-color  ...  stalk-surface-below-ring  \
# 0             0          1           4  ...                         2
# 1             0          0           4  ...                         2
# 2             0          0           5  ...                         2
# 3             0          1           5  ...                         2
# 4             1          0           4  ...                         2
#
#    stalk-color-above-ring  stalk-color-below-ring  veil-type  veil-color  \
# 0                       7                       7          0           2
# 1                       7                       7          0           2
# 2                       7                       7          0           2
# 3                       7                       7          0           2
# 4                       7                       7          0           2
#
#    ring-number  ring-type  spore-print-color  population  habitat
# 0            1          4                  2           3        5
# 1            1          4                  3           2        1
# 2            1          4                  3           2        3
# 3            1          4                  2           3        5
# 4            1          0                  3           0        1
#
# [5 rows x 23 columns]

# %%
df['veil-type'].value_counts()
# Out:
# 0    8124
# Name: veil-type, dtype: int64

# %%
#since veil-type has unique values and might not contribute to dataset dropping it
#df.drop(['veil-type'],axis=1)
df=df.drop(['veil-type'],axis=1) 
df.columns
# Out:
# Index(['class', 'cap-shape', 'cap-surface', 'cap-color', 'bruises', 'odor',
#        'gill-attachment', 'gill-spacing', 'gill-size', 'gill-color',
#        'stalk-shape', 'stalk-root', 'stalk-surface-above-ring',
#        'stalk-surface-below-ring', 'stalk-color-above-ring',
#        'stalk-color-below-ring', 'veil-color', 'ring-number', 'ring-type',
#        'spore-print-color', 'population', 'habitat'],
#       dtype='object')

# %%
#Display correlation between variables
plt.figure(figsize=(15,12))
sns.heatmap(df.corr(),linewidth=0.2,annot=True,annot_kws={'size':7},cmap="YlGnBu")
plt.yticks(rotation=0)
plt.show()

# %% [markdown]
# Since variable gill attachment and veil colour are highly correlated drop one column gill attachment

# %%
df=df.drop(['gill-attachment'],axis=1)

# %%
df.head()
# Out:
#    class  cap-shape  cap-surface  cap-color  bruises  odor  gill-spacing  \
# 0      1          5            2          4        1     6             0
# 1      0          5            2          9        1     0             0
# 2      0          0            2          8        1     3             0
# 3      1          5            3          8        1     6             0
# 4      0          5            2          3        0     5             1
#
#    gill-size  gill-color  stalk-shape  ...  stalk-surface-above-ring  \
# 0          1           4            0  ...                         2
# 1          0           4            0  ...                         2
# 2          0           5            0  ...                         2
# 3          1           5            0  ...                         2
# 4          0           4            1  ...                         2
#
#    stalk-surface-below-ring  stalk-color-above-ring  stalk-color-below-ring  \
# 0                         2                       7                       7
# 1                         2                       7                       7
# 2                         2                       7                       7
# 3                         2                       7                       7
# 4                         2                       7                       7
#
#    veil-color  ring-number  ring-type  spore-print-color  population  habitat
# 0           2            1          4                  2           3        5
# 1           2            1          4                  3           2        1
# 2           2            1          4                  3           2        3
# 3           2            1          4                  2           3        5
# 4           2            1          0                  3           0        1
#
# [5 rows x 21 columns]

# %%
df.shape #feature reduction done from 23 to 21
# Out:
# (8124, 21)

# %%
#Feature Selection into target and features
X=df.drop(['class'],axis=1) 
y=df['class']

# %% [markdown]
# #### Modelling
#
# ##### 1.Logistic Regression
#
# ##### 2.K nearest neighbours
#
# ##### 3.Support vector Machine
#
# ##### 4.Naive Bayes' Classifier
#
# ##### 5.Random forest Classifier
#
# ##### 6.Decision Tree

# %%
#Split dataset
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,random_state=42,train_size=0.75)

# %%
X_train.shape
# Out:
# (6093, 20)

# %%
y_train.shape
# Out:
# (6093,)

# %%
X_test.shape
# Out:
# (2031, 20)

# %%
y_test.shape
# Out:
# (2031,)

# %% [markdown]
# ##### 1 Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
logit_model = LogisticRegression()
logit_model.fit(X_train,y_train)
y_pred = logit_model.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score

# %%
print("Test Accuracy: {}%".format(round(logit_model.score(X_test,y_test)*100,2)))
print("Accuracy is:",accuracy_score(y_test,y_pred))
print("precision is:",precision_score(y_test,y_pred,average="macro"))
print("recall is",recall_score(y_test,y_pred,average="macro"))
print("f1 is",f1_score(y_test,y_pred,average="macro"))
# Out:
# Test Accuracy: 95.52%
# Accuracy is: 0.9551944854751354
# precision is: 0.9551162438852187
# recall is 0.9553229061553985
# f1 is 0.9551804038397882

# %%
cm = pd.DataFrame(confusion_matrix( y_pred,y_test), columns=['Predicted Poison', 'Predicted Edible'], index=['Actual Poison', 'Actual Edible'])
cm
# Out:
#                Predicted Poison  Predicted Edible
# Actual Poison               988                39
# Actual Edible                52               952

# %%
t=[]
t.append(['Logistic Regession',(logit_model.score(X_test,y_test)*100)])

# %% [markdown]
# #### 2.KNeighborsClassifier

# %%
from sklearn.neighbors import KNeighborsClassifier
acc_values=[]
neighbors=np.arange(3,13,2)         # optimum k value is choosen as the square root of the number of datapoints
for k in neighbors:
    classifier=KNeighborsClassifier(n_neighbors=k,metric='minkowski')
    classifier.fit(X_train,y_train)
    y_pred1=classifier.predict(X_test)
    acc=accuracy_score(y_test,y_pred1)
    acc_values.append(acc)

# %%
plt.plot(neighbors,acc_values,'o-')
plt.xlabel('k value')
plt.ylabel('accuracy')
# Out:
# Text(0, 0.5, 'accuracy')

# %%
acc_values
# Out:
# [0.9985228951255539,
#  0.9965534219596258,
#  0.9970457902511078,
#  0.9975381585425899,
#  0.9970457902511078]

# %%
classifier=KNeighborsClassifier(n_neighbors=3,metric='minkowski')   # Replacing k with highest accuracy valu '3'
classifier.fit(X_train,y_train)
y_pred=classifier.predict(X_test)  
print("Test Accuracy: {}%".format(round(classifier.score(X_test,y_test)*100,2)))
# Out:
# Test Accuracy: 99.85%

# %%
t.append(['KNN Classifier',(classifier.score(X_test,y_test)*100)])

# %% [markdown]
# #### 3.Decision Tree Algorithm

# %%
from sklearn.tree import DecisionTreeClassifier
data_model= DecisionTreeClassifier()
data_model.fit(X_train,y_train)
y_pred=data_model.predict(X_test)
print("Test Accuracy: {}%".format(round(data_model.score(X_test,y_test)*100,2)))
# Out:
# Test Accuracy: 100.0%

# %%
t.append(['DecisionTreeClassifier',(data_model.score(X_test,y_test)*100)])

# %% [markdown]
# #### 4. Support vector machine

# %%
from sklearn.svm import SVC
svm_linear = SVC(kernel='linear')     #SVM Linear
svm_linear.fit(X_train,y_train)
y_pred = svm_linear.predict(X_test)
print("Test Accuracy: {}%".format(round(svm_linear.score(X_test,y_test)*100,2)))
# Out:
# Test Accuracy: 96.55%

# %%
t.append(['SVM Radial',(svm_linear.score(X_test,y_test)*100)])

# %%
svm_linear = SVC(kernel='poly',degree=3)     #SVM Polynomial
svm_linear.fit(X_train,y_train)
y_pred = svm_linear.predict(X_test)
print("Test Accuracy: {}%".format(round(svm_linear.score(X_test,y_test)*100,2)))
# Out:
# Test Accuracy: 100.0%

# %%
t.append(['SVM Polynomial',(svm_linear.score(X_test,y_test)*100)])

# %% [markdown]
# #### 5.Random forest algorithm

# %%
from sklearn.ensemble import RandomForestClassifier
rf=RandomForestClassifier()
rf.fit(X_train,y_train)
y_pred=rf.predict(X_test)
print("Test Accuracy: {}%".format(round(rf.score(X_test,y_test)*100,2)))
# Out:
# Test Accuracy: 100.0%

# %%
t.append(['Random forest algorithm',(rf.score(X_test,y_test)*100)])

# %% [markdown]
# #### 6.Naïve Baye's Classifier

# %%
from sklearn.naive_bayes import GaussianNB
classifier=GaussianNB()
classifier.fit(X_train,y_train)
# Out:
# GaussianNB()

# %%
y_pred=classifier.predict(X_test)
y_pred
# Out:
# array([0, 1, 1, ..., 0, 0, 1])

# %%
from sklearn.metrics import confusion_matrix,accuracy_score
cm=confusion_matrix(y_test,y_pred)
accuracy_score(y_test,y_pred) 
print("Test Accuracy: {}%".format(round(classifier.score(X_test,y_test)*100,2)))
# Out:
# Test Accuracy: 93.11%

# %%
t.append(['GaussianNB',(classifier.score(X_test,y_test)*100)])

# %% [markdown]
# #### 7.BernoulliNB

# %%
from sklearn.naive_bayes import BernoulliNB
classifier=BernoulliNB()
classifier.fit(X_train,y_train)
# Out:
# BernoulliNB()

# %%
y_pred=classifier.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix,accuracy_score
cm=confusion_matrix(y_test,y_pred)
accuracy_score(y_test,y_pred)
print("Test Accuracy: {}%".format(round(classifier.score(X_test,y_test)*100,2)))
# Out:
# Test Accuracy: 86.46%

# %%
t.append(['BernoulliNB',(classifier.score(X_test,y_test)*100)])

# %% [markdown]
# #### 8.MultinomialNB

# %%
from sklearn.naive_bayes import MultinomialNB
classifier2= MultinomialNB()
classifier2.fit(X_train,y_train)
y_pred=classifier2.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix,accuracy_score
cm=confusion_matrix(y_test,y_pred)
accuracy_score(y_test,y_pred)
print("Test Accuracy: {}%".format(round(classifier2.score(X_test,y_test)*100,2)))
# Out:
# Test Accuracy: 78.14%

# %%
t.append(['MultinomialNB',(classifier2.score(X_test,y_test)*100)])

# %%
df_result=pd.DataFrame(t, columns=["Algorithms","Accuracy"])
df_result
# Out:
#                 Algorithms    Accuracy
# 0       Logistic Regession   95.519449
# 1           KNN Classifier   99.852290
# 2   DecisionTreeClassifier  100.000000
# 3               SVM Radial   96.553422
# 4           SVM Polynomial  100.000000
# 5  Random forest algorithm  100.000000
# 6               GaussianNB   93.106844
# 7              BernoulliNB   86.459872
# 8            MultinomialNB   78.138848

# %% [markdown]
# #### Conclusion
# ##### Decision Tree, SVM Polynomial, Random Forest scored 100% where as Naive Bayes scored lesser when compared with this top 3 algorithms. 93%, 86%,and 78 % to Gaussian, Bernoulli,Multinomial Naive Bayesian
# #### Therefore Algorithm other than Naive Bayes can be adopted for classify mushroom's edible or poisonous perfectly.
